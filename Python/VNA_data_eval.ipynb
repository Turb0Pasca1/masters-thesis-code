# %% [markdown]
# # VNA Plots

# %%
from matplotlib import pyplot as plt
import rf_functions as rf
import mpl_config
import os
current_dir = os.getcwd()

# %% [markdown]
# # VNA data evaluation

# %%
data_path = os.path.join(current_dir, '..', 'data', 'measurements')
# save_path = os.path.join(current_dir, '..', 'thesis', 'figures', 'vna_plots', 'vna_measurements', 'double_res')

# %%
fname = 'nanoVNA_at_magspec_double_res_NaCl_CuSO4.s1p'
data_name = os.path.join(data_path, fname)

rf.visualize_VNA(datatype='NanoVNA', data_fname = data_name, plot='Z_and_RL', xticksint=False)
# plt.savefig(save_path + '/' + fname.split('.')[0] + '.pdf', bbox_inches='tight')
# Out:
# df = 960.32 kHz
# df = 130.95 kHz

# %%
fname = 'magspec_double_res_1H_NaCl_CuSO4.csv'
data_name = os.path.join(data_path, fname)

xlim = [21.35,21.75]
ylimZ = [-50,100]
ylimRL = [-40, 1]
rf.visualize_VNA(datatype='magspec', data_fname = data_name, plot='Z_and_RL', xticksint=False, ylimZ=ylimZ, ylimRL=ylimRL, xlim=xlim)
# plt.savefig(save_path + '/' + fname.split('.')[0] + '.pdf', bbox_inches='tight')
# Out:
# df = 922.62 kHz
